# %%
import marimo as mo

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/customer-transaction-dataset/sample_dataset.csv')
df
# Out:
# <marimo-ui-element object-id='YTdc-0' random-id='4d5b960a-905b-4bca-8016-fcf97ebf8192'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;Customer ID&#92;&quot;:752858,&#92;&quot;Name&#92;&quot;:&#92;&quot;Sean&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Rodriguez&#92;&quot;,&#92;&quot;Gender&#92;&quot;:&#92;&quot;F&#92;&quot;,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;2002-10-20&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:35.47,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-04-03&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Smith-Russell&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Cosmetic&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:26381,&#92;&quot;Name&#92;&quot;:&#92;&quot;Michelle&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Phelps&#92;&quot;,&#92;&quot;Gender&#92;&quot;:null,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;1985-10-24&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:2552.72,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-07-17&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Peck, Spence and Young&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Travel&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:305449,&#92;&quot;Name&#92;&quot;:&#92;&quot;Jacob&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Williams&#92;&quot;,&#92;&quot;Gender&#92;&quot;:&#92;&quot;M&#92;&quot;,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;1981-10-25&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:115.97,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-09-20&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Steele Inc&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Clothing&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:988259,&#92;&quot;Name&#92;&quot;:&#92;&quot;Nathan&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Snyder&#92;&quot;,&#92;&quot;Gender&#92;&quot;:&#92;&quot;M&#92;&quot;,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;1977-10-26&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:11.31,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-01-11&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Wilson, Wilson and Russell&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Cosmetic&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:764762,&#92;&quot;Name&#92;&quot;:&#92;&quot;Crystal&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Knapp&#92;&quot;,&#92;&quot;Gender&#92;&quot;:&#92;&quot;F&#92;&quot;,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;1951-11-02&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:62.21,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-06-13&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Palmer-Hinton&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Electronics&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:576539,&#92;&quot;Name&#92;&quot;:&#92;&quot;Monica&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Bartlett&#92;&quot;,&#92;&quot;Gender&#92;&quot;:&#92;&quot;F&#92;&quot;,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;2001-10-20&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:99.14,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-08-24&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Tran, Torres and Joyce&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Cosmetic&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:124681,&#92;&quot;Name&#92;&quot;:&#92;&quot;Thomas&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Shaw&#92;&quot;,&#92;&quot;Gender&#92;&quot;:null,&#92;&quot;Birthdate&#92;&quot;:&#92;&quot;1976-10-26&#92;&quot;,&#92;&quot;Transaction Amount&#92;&quot;:145.94,&#92;&quot;Date&#92;&quot;:&#92;&quot;2023-08-30&#92;&quot;,&#92;&quot;Merchant Name&#92;&quot;:&#92;&quot;Evans, Griffin and Torres&#92;&quot;,&#92;&quot;Category&#92;&quot;:&#92;&quot;Cosmetic&#92;&quot;},{&#92;&quot;Customer ID&#92;&quot;:521807,&#92;&quot;Name&#92;&quot;:&#92;&quot;Kelsey&#92;&quot;,&#92;&quot;Surname&#92;&quot;:&#92;&quot;Pena&#92;&quot;,&#92;&quot;Gender&#92;&quot;:&#92;&quot;F&#92;&quot;,&# ...

# %%
df.columns
# Out:
# <pre style='font-size: 12px'>Index([&#x27;Customer ID&#x27;, &#x27;Name&#x27;, &#x27;Surname&#x27;, &#x27;Gender&#x27;, &#x27;Birthdate&#x27;,
#        &#x27;Transaction Amount&#x27;, &#x27;Date&#x27;, &#x27;Merchant Name&#x27;, &#x27;Category&#x27;],
#       dtype=&#x27;object&#x27;)</pre>

# %%
df.columns = [name.lower() for name in df.columns]
df.columns
# Out:
# <pre style='font-size: 12px'>Index([&#x27;customer id&#x27;, &#x27;name&#x27;, &#x27;surname&#x27;, &#x27;gender&#x27;, &#x27;birthdate&#x27;,
#        &#x27;transaction amount&#x27;, &#x27;date&#x27;, &#x27;merchant name&#x27;, &#x27;category&#x27;],
#       dtype=&#x27;object&#x27;)</pre>

# %%
s = pd.Series(np.arange(10))
div, rem = divmod(s, 3)
print(rem)
div
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    1
# 5    2
# 6    0
# 7    1
# 8    2
# 9    0
# dtype: int64

# %% [markdown]
# ## Missing data / operations with fill values

# %%
series_df = pd.DataFrame({
    'one': [1, 2, 9, 4],
    'two': [5, 6, 7, None]
}, index=list('abcd'))

series_df
# Out:
# <marimo-ui-element object-id='zfft-0' random-id='1a7b6c7e-ebc3-4fb0-0261-b676b9104f48'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;&#92;&quot;:&#92;&quot;a&#92;&quot;,&#92;&quot;one&#92;&quot;:1,&#92;&quot;two&#92;&quot;:5.0},{&#92;&quot;&#92;&quot;:&#92;&quot;b&#92;&quot;,&#92;&quot;one&#92;&quot;:2,&#92;&quot;two&#92;&quot;:6.0},{&#92;&quot;&#92;&quot;:&#92;&quot;c&#92;&quot;,&#92;&quot;one&#92;&quot;:9,&#92;&quot;two&#92;&quot;:7.0},{&#92;&quot;&#92;&quot;:&#92;&quot;d&#92;&quot;,&#92;&quot;one&#92;&quot;:4,&#92;&quot;two&#92;&quot;:null}]&quot;' data-total-rows='4' data-total-columns='2' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;one&quot;, [&quot;integer&quot;, &quot;int64&quot;]], [&quot;two&quot;, [&quot;number&quot;, &quot;float64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-row-headers='[&quot;&quot;]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
series_df['one'].add(series_df['two'], fill_value=0)
# Out:
# <marimo-ui-element object-id='OJkA-0' random-id='1d8ccb9c-568e-2257-055d-24b9265c1e1c'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;&#92;&quot;:&#92;&quot;a&#92;&quot;,&#92;&quot;value&#92;&quot;:6.0},{&#92;&quot;&#92;&quot;:&#92;&quot;b&#92;&quot;,&#92;&quot;value&#92;&quot;:8.0},{&#92;&quot;&#92;&quot;:&#92;&quot;c&#92;&quot;,&#92;&quot;value&#92;&quot;:16.0},{&#92;&quot;&#92;&quot;:&#92;&quot;d&#92;&quot;,&#92;&quot;value&#92;&quot;:4.0}]&quot;' data-total-rows='4' data-total-columns='1' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;value&quot;, [&quot;number&quot;, &quot;float64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-row-headers='[&quot;&quot;]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
series_df['one'].add(series_df['two'], fill_value=55)
# Out:
# <marimo-ui-element object-id='JlNN-0' random-id='3d3ea92a-7dfa-dd66-47f8-c4c53236b598'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;&#92;&quot;:&#92;&quot;a&#92;&quot;,&#92;&quot;value&#92;&quot;:6.0},{&#92;&quot;&#92;&quot;:&#92;&quot;b&#92;&quot;,&#92;&quot;value&#92;&quot;:8.0},{&#92;&quot;&#92;&quot;:&#92;&quot;c&#92;&quot;,&#92;&quot;value&#92;&quot;:16.0},{&#92;&quot;&#92;&quot;:&#92;&quot;d&#92;&quot;,&#92;&quot;value&#92;&quot;:59.0}]&quot;' data-total-rows='4' data-total-columns='1' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;value&quot;, [&quot;number&quot;, &quot;float64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-row-headers='[&quot;&quot;]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %% [markdown]
# ## Flexible comparisons
# ### ```eq, ne, lt, gt, le, and ge```

# %%
series_df['one'].gt(series_df['two'])
# Out:
# <marimo-ui-element object-id='GphZ-0' random-id='bea00c4b-8990-6339-e794-517a4873e28e'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;&#92;&quot;:&#92;&quot;a&#92;&quot;,&#92;&quot;value&#92;&quot;:false},{&#92;&quot;&#92;&quot;:&#92;&quot;b&#92;&quot;,&#92;&quot;value&#92;&quot;:false},{&#92;&quot;&#92;&quot;:&#92;&quot;c&#92;&quot;,&#92;&quot;value&#92;&quot;:true},{&#92;&quot;&#92;&quot;:&#92;&quot;d&#92;&quot;,&#92;&quot;value&#92;&quot;:false}]&quot;' data-total-rows='4' data-total-columns='1' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;value&quot;, [&quot;boolean&quot;, &quot;bool&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-row-headers='[&quot;&quot;]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %% [markdown]
# ## Boolean reductions
# ### ```empty, any(), all(), and bool()```

# %%
np.nan == np.nan
# Out:
# <pre style='font-size: 12px'>False</pre>

# %%
(series_df + series_df).equals(series_df * 2)
# Out:
# <pre style='font-size: 12px'>True</pre>

# %% [markdown]
# ## Combining overlapping data sets
# ### ```combine_first()```
